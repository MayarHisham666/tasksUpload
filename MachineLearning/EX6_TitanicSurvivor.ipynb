# %%
import pandas as pd

# %%
titanic=pd.read_csv('titanic.csv')
titanic.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                            Emir, Mr. Farred Chehab    male   NaN      0
# 27                     Fortune, Mr. Charles Alexander    male  19.0      3
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                Todoroff, Mr. Lalio    male   NaN      0
#
#     Parch            Ticket      Fare        Cabin Embarked
# 0       0         A/5 21171    7.2500          NaN        S
# 1       0          PC 17599   71.2833          C85        C
# 2       0  STON/O2. 3101282    7.9250          NaN        S
# 3       0            113803   53.1000         C123        S
# 4       0            373450    8.0500          NaN        S
# 5       0            330877    8.4583          NaN        Q
# 6       0             17463   51.8625          E46        S
# 7       1            349909   21.0750          NaN        S
# 8       2            347742   11.1333          NaN        S
# 9       0            237736   30.0708          NaN        C
# 10      1           PP 9549   16.7000           G6        S
# 11      0            113783   26.5500         C103        S
# 12      0         A/5. 2151    8.0500          NaN        S
# 13      5            347082   31.2750          NaN        S
# 14      0            350406    7.8542          NaN        S
# 15      0            248706   16.0000          NaN        S
# 16      1            382652   29.1250          NaN        Q
# 17      0            244373   13.0000          NaN        S
# 18      0            345763   18.0000          NaN        S
# 19      0              2649    7.2250          NaN        C
# 20      0            239865   26.0000          NaN        S
# 21      0            248698   13.0000          D56        S
# 22      0            330923    8.0292          NaN        Q
# 23      0            113788   35.5000           A6        S
# 24      1            349909   21.0750          NaN        S
# 25      5            347077   31.3875          NaN        S
# 26      0              2631    7.2250          NaN        C
# 27      2             19950  263.0000  C23 C25 C27        S
# 28      0            330959    7.8792          NaN        Q
# 29      0            349216    7.8958          NaN        S

# %%
titanicList=titanic[['Survived','Pclass','Name','SibSp','Parch','Fare','Embarked']]
titanicList
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#      SibSp  Parch     Fare Embarked
# 0        1      0   7.2500        S
# 1        1      0  71.2833        C
# 2        0      0   7.9250        S
# 3        1      0  53.1000        S
# 4        0      0   8.0500        S
# ..     ...    ...      ...      ...
# 886      0      0  13.0000        S
# 887      0      0  30.0000        S
# 888      1      2  23.4500        S
# 889      0      0  30.0000        C
# 890      0      0   7.7500        Q
#
# [891 rows x 7 columns]

# %%
titanicList_dummies=pd.get_dummies(titanicList.Embarked)
titanicList_dummies
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
titanicList_concat=pd.concat([titanicList,titanicList_dummies],axis='columns')
titanicList_concat
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#      SibSp  Parch     Fare Embarked  C  Q  S
# 0        1      0   7.2500        S  0  0  1
# 1        1      0  71.2833        C  1  0  0
# 2        0      0   7.9250        S  0  0  1
# 3        1      0  53.1000        S  0  0  1
# 4        0      0   8.0500        S  0  0  1
# ..     ...    ...      ...      ... .. .. ..
# 886      0      0  13.0000        S  0  0  1
# 887      0      0  30.0000        S  0  0  1
# 888      1      2  23.4500        S  0  0  1
# 889      0      0  30.0000        C  1  0  0
# 890      0      0   7.7500        Q  0  1  0
#
# [891 rows x 10 columns]

# %%
titanicData=titanicList_concat.drop("Embarked",axis='columns')
titanicData
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#      SibSp  Parch     Fare  C  Q  S
# 0        1      0   7.2500  0  0  1
# 1        1      0  71.2833  1  0  0
# 2        0      0   7.9250  0  0  1
# 3        1      0  53.1000  0  0  1
# 4        0      0   8.0500  0  0  1
# ..     ...    ...      ... .. .. ..
# 886      0      0  13.0000  0  0  1
# 887      0      0  30.0000  0  0  1
# 888      1      2  23.4500  0  0  1
# 889      0      0  30.0000  1  0  0
# 890      0      0   7.7500  0  1  0
#
# [891 rows x 9 columns]

# %%
x=titanicData.drop("Name",axis='columns')
y=titanicData.Name

# %%
from sklearn import tree
model=tree.DecisionTreeClassifier()

# %%
model.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
model.score(x,y)
# Out:
# 0.49270482603815935

# %%
model.predict([[1,3,1,0,47.3,0,0,1]])
# Out:
# array(['Angle, Mrs. William A (Florence "Mary" Agnes Hughes)'],
#       dtype=object)

# %%
model.predict([[1,1,1,0,86.74,0,1,0]])
# Out:
# array(['Minahan, Miss. Daisy E'], dtype=object)

# %%
model.feature_importances_
# Out:
# array([0.00684932, 0.07990868, 0.05707763, 0.05707763, 0.78995434,
#        0.00228311, 0.00456621, 0.00228311])

# %%
tt=titanic[['Pclass','Sex','Age','Fare',]]
tt.head(10)
# Out:
#    Pclass     Sex   Age     Fare
# 0       3    male  22.0   7.2500
# 1       1  female  38.0  71.2833
# 2       3  female  26.0   7.9250
# 3       1  female  35.0  53.1000
# 4       3    male  35.0   8.0500
# 5       3    male   NaN   8.4583
# 6       1    male  54.0  51.8625
# 7       3    male   2.0  21.0750
# 8       3  female  27.0  11.1333
# 9       2  female  14.0  30.0708

# %%
tt.fillna(0.0,inplace=True)
tt.head(10)
# Out:
# C:\Users\mayar\anaconda3\lib\site-packages\pandas\core\frame.py:4317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#    Pclass     Sex   Age     Fare
# 0       3    male  22.0   7.2500
# 1       1  female  38.0  71.2833
# 2       3  female  26.0   7.9250
# 3       1  female  35.0  53.1000
# 4       3    male  35.0   8.0500
# 5       3    male   0.0   8.4583
# 6       1    male  54.0  51.8625
# 7       3    male   2.0  21.0750
# 8       3  female  27.0  11.1333
# 9       2  female  14.0  30.0708

# %%
from sklearn.preprocessing import LabelEncoder
tt['sex_n']=LabelEncoder().fit_transform(tt.Sex)
td=tt.drop('Sex',axis='columns')
td
# Out:
# <ipython-input-111-d62cff55923a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt['sex_n']=LabelEncoder().fit_transform(tt.Sex)
#      Pclass   Age     Fare  sex_n
# 0         3  22.0   7.2500      1
# 1         1  38.0  71.2833      0
# 2         3  26.0   7.9250      0
# 3         1  35.0  53.1000      0
# 4         3  35.0   8.0500      1
# ..      ...   ...      ...    ...
# 886       2  27.0  13.0000      1
# 887       1  19.0  30.0000      0
# 888       3   0.0  23.4500      0
# 889       1  26.0  30.0000      1
# 890       3  32.0   7.7500      1
#
# [891 rows x 4 columns]

# %%
inputs=td.drop('sex_n',axis='columns')
inputs
# Out:
#      Pclass   Age     Fare
# 0         3  22.0   7.2500
# 1         1  38.0  71.2833
# 2         3  26.0   7.9250
# 3         1  35.0  53.1000
# 4         3  35.0   8.0500
# ..      ...   ...      ...
# 886       2  27.0  13.0000
# 887       1  19.0  30.0000
# 888       3   0.0  23.4500
# 889       1  26.0  30.0000
# 890       3  32.0   7.7500
#
# [891 rows x 3 columns]

# %%
target=td.sex_n
target
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: sex_n, Length: 891, dtype: int32

# %%
modelII=tree.DecisionTreeClassifier()

# %%
modelII.fit(inputs,target)
# Out:
# DecisionTreeClassifier()

# %%
modelII.score(inputs,target)
# Out:
# 0.941638608305275

# %%
modelII.predict([[3,22,54.000]])
# Out:
# array([0])

# %%
modelII.predict([[2,7,8.700]])
# Out:
# array([1])

# %%
modelII.feature_importances_
# Out:
# array([0.02229261, 0.44093568, 0.5367717 ])
